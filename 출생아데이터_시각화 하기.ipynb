# %% [markdown]
# # [인프런 - 나도코딩 : 데이터 분석 및 시각화(활용편5)](https://www.inflearn.com/course/%EB%82%98%EB%8F%84%EC%BD%94%EB%94%A9-%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D-%EC%8B%9C%EA%B0%81%ED%99%94/dashboard)
#
# - [e-나라지표 출생아 데이터](https://www.index.go.kr/unity/potal/main/EachDtlPageDetail.do?idx_cd=1428)
# - 출생아수 및 합계출산율 알아보기
# - 1980년 ~ 2023년 데이터

# %%
# 코랩 한글 설정
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (26.8 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
# 폰트 설정
plt.rc('font' , family='NanumBarunGothic')

# %%
#skiprows : 3번째 행을 컬럼으로 설정, nrows : 그 밑에 두개 행만 가져옴, index_col : 첫번째 열을 인덱스로 설정
# pd.read_excel("/content/drive/MyDrive/복습용/인프런_나도코딩/프로젝트/data.xlsx", skiprows=2, nrows=2, index_col=0)
df = pd.read_excel("/content/drive/MyDrive/복습용/인프런_나도코딩/프로젝트/data.xlsx", skiprows=2, nrows=2, index_col=0)
df
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           1980    1981    1982    1983    1984    1985    1986    1987  \
# 출생아 수   863.00  867.00  848.00  769.00  675.00  655.00  636.00  624.00
# 합계 출산율    2.82    2.57    2.39    2.06    1.74    1.66    1.58    1.53
#
#           1988    1989  ...     2014     2015     2016     2017     2018  \
# 출생아 수   633.00  639.00  ...  435.400  438.400  406.200  357.800  326.800
# 합계 출산율    1.55    1.56  ...    1.205    1.239    1.172    1.052    0.977
#
#            2019     2020     2021    2022    2023
# 출생아 수   302.700  272.300  260.600  249.10  230.00
# 합계 출산율    0.918    0.837    0.808    0.78    0.72
#
# [2 rows x 44 columns]

# %%
df.loc['출생아 수']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '출생아 수'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-842e9d6a947d> in <cell line: 1>()
# ----> 1 df.loc['출생아 수']
#
# ...

# %%
df.index
# Out:
# Index(['출생아 수', '합계 출산율'], dtype='object')

# %%
df.index.values
# Out:
# array(['출생아\xa0수', '합계\xa0출산율'], dtype=object)

# %%
#인덱스값 재설정
df.rename(index={'출생아\xa0수':'출생아 수', '합계\xa0출산율':'합계 출산율'})
df.rename(index={'출생아\xa0수':'출생아 수', '합계\xa0출산율':'합계 출산율'}, inplace=True)

# %%
df
# Out:
#           1980    1981    1982    1983    1984    1985    1986    1987  \
# 출생아 수   863.00  867.00  848.00  769.00  675.00  655.00  636.00  624.00
# 합계 출산율    2.82    2.57    2.39    2.06    1.74    1.66    1.58    1.53
#
#           1988    1989  ...     2014     2015     2016     2017     2018  \
# 출생아 수   633.00  639.00  ...  435.400  438.400  406.200  357.800  326.800
# 합계 출산율    1.55    1.56  ...    1.205    1.239    1.172    1.052    0.977
#
#            2019     2020     2021    2022    2023
# 출생아 수   302.700  272.300  260.600  249.10  230.00
# 합계 출산율    0.918    0.837    0.808    0.78    0.72
#
# [2 rows x 44 columns]

# %%
df.index.values
# Out:
# array(['출생아 수', '합계 출산율'], dtype=object)

# %%
df.loc['출생아 수']
# Out:
# 1980    863.0
# 1981    867.0
# 1982    848.0
# 1983    769.0
# 1984    675.0
# 1985    655.0
# 1986    636.0
# 1987    624.0
# 1988    633.0
# 1989    639.0
# 1990    650.0
# 1991    709.0
# 1992    731.0
# 1993    716.0
# 1994    721.0
# 1995    715.0
# 1996    691.0
# 1997    675.4
# 1998    641.6
# 1999    620.7
# 2000    640.1
# 2001    559.9
# 2002    496.9
# 2003    495.0
# 2004    477.0
# 2005    438.7
# 2006    451.8
# 2007    496.8
# 2008    465.9
# 2009    444.8
# 2010    470.2
# 2011    471.3
# 2012    484.6
# 2013    436.5
# 2014    435.4
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# 2021    260.6
# 2022    249.1
# 2023    230.0
# Name: 출생아 수, dtype: float64

# %%
df.iloc[0]
# Out:
# 1980    863.0
# 1981    867.0
# 1982    848.0
# 1983    769.0
# 1984    675.0
# 1985    655.0
# 1986    636.0
# 1987    624.0
# 1988    633.0
# 1989    639.0
# 1990    650.0
# 1991    709.0
# 1992    731.0
# 1993    716.0
# 1994    721.0
# 1995    715.0
# 1996    691.0
# 1997    675.4
# 1998    641.6
# 1999    620.7
# 2000    640.1
# 2001    559.9
# 2002    496.9
# 2003    495.0
# 2004    477.0
# 2005    438.7
# 2006    451.8
# 2007    496.8
# 2008    465.9
# 2009    444.8
# 2010    470.2
# 2011    471.3
# 2012    484.6
# 2013    436.5
# 2014    435.4
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# 2021    260.6
# 2022    249.1
# 2023    230.0
# Name: 출생아 수, dtype: float64

# %%
df.T
df = df.T
df
# Out:
#       출생아 수  합계 출산율
# 1980  863.0   2.820
# 1981  867.0   2.570
# 1982  848.0   2.390
# 1983  769.0   2.060
# 1984  675.0   1.740
# 1985  655.0   1.660
# 1986  636.0   1.580
# 1987  624.0   1.530
# 1988  633.0   1.550
# 1989  639.0   1.560
# 1990  650.0   1.570
# 1991  709.0   1.710
# 1992  731.0   1.760
# 1993  716.0   1.654
# 1994  721.0   1.656
# 1995  715.0   1.634
# 1996  691.0   1.574
# 1997  675.4   1.537
# 1998  641.6   1.464
# 1999  620.7   1.425
# 2000  640.1   1.480
# 2001  559.9   1.309
# 2002  496.9   1.178
# 2003  495.0   1.191
# 2004  477.0   1.164
# 2005  438.7   1.085
# 2006  451.8   1.132
# 2007  496.8   1.259
# 2008  465.9   1.192
# 2009  444.8   1.149
# 2010  470.2   1.226
# 2011  471.3   1.244
# 2012  484.6   1.297
# 2013  436.5   1.187
# 2014  435.4   1.205
# 2015  438.4   1.239
# 2016  406.2   1.172
# 2017  357.8   1.052
# 2018  326.8   0.977
# 2019  302.7   0.918
# 2020  272.3   0.837
# 2021  260.6   0.808
# 2022  249.1   0.780
# 2023  230.0   0.720

# %% [markdown]
# # 시각화

# %%
# 그래프 설정
plt.rcParams['font.size'] = 10
plt.rcParams['figure.figsize'] = 20, 10
plt.rcParams['axes.unicode_minus'] = False

# %%
plt.plot(df.index, df['출생아 수'])
plt.show()

# %% [markdown]
# ## 두개의 데이터를 하나의 그래프로

# %%
fig, ax1 = plt.subplots(figsize=(20, 10))
ax1.plot(df.index, df['출생아 수'])

ax2 = ax1.twinx() # x축을 공유하는 쌍둥이 axis
ax2.plot(df.index, df['합계 출산율'], color='red')

ax1.set_xlabel('연도')
ax1.set_ylabel('출생아 수')
ax2.set_ylabel('합계 출산율')

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(20, 10))
ax1.set_ylabel('출생아 수(천명)')
ax1.set_ylim(0, 1000)
ax1.set_yticks(range(0, 1000, 300))
ax1.bar(df.index, df['출생아 수'], color='orange')

ax2 = ax1.twinx() # x축을 공유하는 쌍둥이 axis
ax2.set_ylabel('합계 출산율(가임여성 1명당 명)')
ax2.set_ylim(0, 3)
ax2.set_yticks(range(0, 3, 1))
ax2.plot(df.index, df['합계 출산율'], color='blue', marker='D')

ax1.set_xlabel('연도')


plt.show()

# %% [markdown]
# ## 막대 그래프 위에 값 추가하기

# %%
import matplotlib.pyplot as plt

# 그래프 설정
fig, ax1 = plt.subplots(figsize=(20, 10))
ax1.set_ylabel('출생아 수(천명)')
ax1.set_ylim(0, 1000)
ax1.set_yticks(range(0, 1000, 300))
bars = ax1.bar(df.index, df['출생아 수'], color='orange')

# 막대 위에 값 추가
for bar in bars:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval, f'{yval}', ha='center', va='bottom')

# 쌍둥이 y축 설정
ax2 = ax1.twinx()
ax2.set_ylabel('합계 출산율(가임여성 1명당 명)')
ax2.set_ylim(0, 3)
ax2.set_yticks(range(0, 4, 1))
ax2.plot(df.index, df['합계 출산율'], color='blue', marker='D')

ax1.set_xlabel('연도')

plt.show()

# %%
import matplotlib.pyplot as plt

# 그래프 설정
fig, ax1 = plt.subplots(figsize=(20, 10))
ax1.set_ylabel('출생아 수(천명)')
ax1.set_ylim(0, 1000)
ax1.set_yticks(range(0, 1000, 300))
bars = ax1.bar(df.index, df['출생아 수'], color='orange')

# 막대 위에 값 추가
for bar in bars:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval, f'{yval}', ha='center', va='bottom')

# 쌍둥이 y축 설정
ax2 = ax1.twinx()
ax2.set_ylabel('합계 출산율(가임여성 1명당 명)')
ax2.set_ylim(0, 3)
ax2.set_yticks(range(0, 4, 1))
line, = ax2.plot(df.index, df['합계 출산율'], color='blue', marker='D')

# 선 위에 값 추가
for i, value in enumerate(df['합계 출산율']):
    ax2.text(df.index[i], value, f'{value:.2f}', ha='center', va='bottom')

ax1.set_xlabel('연도')

plt.show()
